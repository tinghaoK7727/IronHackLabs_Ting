# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'/Users/tinghaokao/Desktop/IronHackDA/DAFT_212/module_3/Lab_3_Data-Cleaning-Challenge/iris-data.csv')

# %%
data.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
features = data[['sepal_length_cm','sepal_width_cm','petal_length_cm','petal_width_cm']]

# %%
features.head()
Target=data['class']

# %%
from sklearn.preprocessing import StandardScaler
features_st = StandardScaler().fit_transform(features)

# %%
features_st
# Out:
# array([[-0.41625454,  1.03163593, -1.3412724 , -1.37756865],
#        [-0.56911321, -0.12663794, -1.3412724 , -1.37756865],
#        [-0.72197188,  0.33667161, -1.39813811, -1.37756865],
#        [-0.79840121,  0.10501683, -1.2844067 , -1.37756865],
#        [-0.49268387,  1.26329071, -1.3412724 , -1.37756865],
#        [-0.18696653,  1.95825503, -1.17067529, -1.11177031],
#        [-0.79840121,  0.79998116, -1.3412724 , -1.24466948],
#        [-0.49268387,  0.79998116, -1.2844067 ,         nan],
#        [-0.95125988, -0.35829272, -1.3412724 ,         nan],
#        [-0.56911321,  0.10501683, -1.2844067 ,         nan],
#        [-0.18696653,  1.49494548, -1.2844067 ,         nan],
#        [-0.64554254,  0.79998116, -1.227541  ,         nan],
#        [-0.64554254, -0.12663794, -1.3412724 , -1.51046782],
#        [ 0.04232147, -0.12663794, -1.51186952, -1.51046782],
#        [ 0.1187508 ,  2.18990981, -1.45500381, -1.37756865],
# ...

# %%
features_st_mean = np.mean(features_st, axis=0)
cov_mat = (features_st - features_st_mean).T.dot((features_st - features_st_mean)) / (features_st.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
# [[ 1.00671141  0.06653433  0.49236552         nan]
#  [ 0.06653433  1.00671141 -0.42261314         nan]
#  [ 0.49236552 -0.42261314  1.00671141         nan]
#  [        nan         nan         nan         nan]]

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /var/folders/9y/45l79l3x40s95c93b61_6txw0000gn/T/ipykernel_80708/1072633789.py in <module>
# ----> 1 eig_vals, eig_vecs = np.linalg.eig(cov_mat)
#       2
#       3 print('Eigenvectors \n%s' %eig_vecs)
#       4 print('\nEigenvalues \n%s' %eig_vals)
#
# <__array_function__ internals> in eig(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/linalg/linalg.py in eig(a)
#    1315     _assert_stacked_2d(a)
#    1316     _assert_stacked_square(a)
# -> 1317     _assert_finite(a)
#    1318     t, result_t = _commonType(a)
#    1319
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/linalg/linalg.py in _assert_finite(*arrays)
#     206     for a in arrays:
#     207         if not isfinite(a).all():
# --> 208             raise LinAlgError("Array must not contain infs or NaNs")
#     209
# ...
