# %%
pip install stackapi
# Out:
# Requirement already satisfied: stackapi in /Users/tinghaokao/opt/anaconda3/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: requests in /Users/tinghaokao/opt/anaconda3/lib/python3.9/site-packages (from stackapi) (2.27.1)
# Requirement already satisfied: six in /Users/tinghaokao/opt/anaconda3/lib/python3.9/site-packages (from stackapi) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tinghaokao/opt/anaconda3/lib/python3.9/site-packages (from requests->stackapi) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/tinghaokao/opt/anaconda3/lib/python3.9/site-packages (from requests->stackapi) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tinghaokao/opt/anaconda3/lib/python3.9/site-packages (from requests->stackapi) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tinghaokao/opt/anaconda3/lib/python3.9/site-packages (from requests->stackapi) (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Question 1: Find the questions and answers of last month.

# %%
from datetime import date
from datetime import datetime
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=datetime(2022,2,1), todate=datetime(2022,2,28))
answers = SITE.fetch('answers', fromdate=datetime(2022,2,1), todate=datetime(2022,2,28))
questions
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 273,
#  'total': 0,
#  'items': [{'owner': {'reputation': 154,
#     'user_id': 8661555,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/gpgEK.jpg?s=256&g=1',
#     'display_name': 'ijmorales',
#     'link': 'https://stackoverflow.com/users/8661555/ijmorales'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646229975,
#    'last_edit_date': 1646229975,
#    'creation_date': 1645204954,
#    'answer_id': 71177510,
#    'question_id': 70683719,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 18322036,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJyWeQLZztpK0uKMqSgE6Cpy4REZGkTa9EGjEiYK=k-s256',
#     'display_name': 'Venkata Ramana',
#     'link': 'https://stackoverflow.com/users/18322036/venkata-ramana'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1646229786,
#    'last_edit_date': 1646229786,
#    'creation_date': 1645953592,
#    'answer_id': 71283537,
#    'question_id': 36001482,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2161,
#     'user_id': 17743647,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwhZrCeT7Dcb68CL8s_M3ajTuYfxAPVdgTOqPbh=k-s256',
#     'display_name': 'James',
#     'link': 'https://stackoverflow.com/users/17743647/james'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646229630,
#    'last_edit_date': 1646229630,
#    'creation_date': 1645809839,
#    'answer_id': 71269510,
#    'question_id': 71268955,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2167,
#     'user_id': 4066742,
#     'user_type': 'registered',
#     'accept_rate': 0,
#     'profile_image': 'https://i.stack.imgur.com/VebTa.jpg?s=256&g=1',
#     'display_name': 'S. Mayol',
#     'link': 'https://stackoverflow.com/users/4066742/s-mayol'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646228985,
#    'last_edit_date': 1646228985,
#    'creation_date': 1644254339,
#    'answer_id': 71022642,
#    'question_id': 54050227,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1554,
#     'user_id': 7965567,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-tjSNx-IK9_I/AAAAAAAAAAI/AAAAAAAAAAA/rBrUswZkH5o/photo.jpg?sz=256',
#     'display_name': 'Edi Imanto',
#     'link': 'https://stackoverflow.com/users/7965567/edi-imanto'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646228964,
#    'last_edit_date': 1646228964,
#    'creation_date': 1645510165,
#    'answer_id': 71216631,
#    'question_id': 71206772,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 775,
#     'user_id': 14819065,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/HL5fu.jpg?s=256&g=1',
#     'display_name': 'Omar Magdy',
#     'link': 'https://stackoverflow.com/users/14819065/omar-magdy'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1646228298,
#    'last_edit_date': 1646228298,
#    'creation_date': 1645090714,
#    'answer_id': 71155621,
#    'question_id': 43862600,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 16,
#     'user_id': 7382853,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/758a55e701ec15f43d112d176bfa4494?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'C. Coşgun',
#     'link': 'https://stackoverflow.com/users/7382853/c-co%c5%9fgun'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646227545,
#    'last_edit_date': 1646227545,
#    'creation_date': 1645689437,
#    'answer_id': 71248761,
#    'question_id': 71248685,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 16639921,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgFLHepKJ2ptro8MqIPq2OosEauYRVmFQu9bYKpqw=k-s256',
#     'display_name': 'Ajay Singh Bhadauriya',
#     'link': 'https://stackoverflow.com/users/16639921/ajay-singh-bhadauriya'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1646227335,
#    'last_edit_date': 1646227335,
#    'creation_date': 1645690470,
#    'answer_id': 71248928,
#    'question_id': 64867504,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 56624,
#     'user_id': 1100107,
#     'user_type': 'registered',
#     'accept_rate': 80,
#     'profile_image': 'https://www.gravatar.com/avatar/8789d3da0b482bcd8e562bfdf3687c74?s=256&d=identicon&r=PG',
#     'display_name': 'St&#233;phane Laurent',
#     'link': 'https://stackoverflow.com/users/1100107/st%c3%a9phane-laurent'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646227169,
#    'last_edit_date': 1646227169,
#    'creation_date': 1645878322,
#    'answer_id': 71276629,
#    'question_id': 71275644,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 12247,
#     'user_id': 7380779,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/10211702939720023/picture?type=large',
#     'display_name': 'Frenchy',
#     'link': 'https://stackoverflow.com/users/7380779/frenchy'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646225703,
#    'last_edit_date': 1646225703,
#    'creation_date': 1645443356,
#    'answer_id': 71205646,
#    'question_id': 71203779,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 3,
#     'user_id': 15802748,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/z4Dti.png?s=256&g=1',
#     'display_name': 'Xavida',
#     'link': 'https://stackoverflow.com/users/15802748/xavida'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646225391,
#    'last_edit_date': 1646225391,
#    'creation_date': 1644068893,
#    'answer_id': 70998625,
#    'question_id': 70998609,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 14126692,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgEBFzsz4DS3bTDpi9Aj6OZdo4krvvPaW-M44Cy2A=k-s256',
#     'display_name': 'Lalith Yagnavalkya',
#     'link': 'https://stackoverflow.com/users/14126692/lalith-yagnavalkya'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646225323,
#    'last_edit_date': 1646225323,
#    'creation_date': 1645729467,
#    'answer_id': 71257017,
#    'question_id': 57736419,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 18303045,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgnDtnX8VnL8ajNM13rKYd0NBtpmTSTj1gaAb7ppg=k-s256',
#     'display_name': 'mututa paul',
#     'link': 'https://stackoverflow.com/users/18303045/mututa-paul'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646225123,
#    'last_edit_date': 1646225123,
#    'creation_date': 1645739087,
#    'answer_id': 71258626,
#    'question_id': 51525710,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 146813,
#     'user_id': 7252182,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/LUgxG.png?s=256&g=1',
#     'display_name': 'mm8',
#     'link': 'https://stackoverflow.com/users/7252182/mm8'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1646225030,
#    'last_edit_date': 1646225030,
#    'creation_date': 1645546439,
#    'answer_id': 71224635,
#    'question_id': 71209803,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 18303295,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/37aef3512110abaa85ee1312439e00fa?s=256&d=identicon&r=PG',
#     'display_name': 'ctong',
#     'link': 'https://stackoverflow.com/users/18303295/ctong'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646224901,
#    'last_edit_date': 1646224901,
#    'creation_date': 1645742135,
#    'answer_id': 71259043,
#    'question_id': 35443817,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 33,
#     'user_id': 13350535,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7c5905128063cc3542d9aac383b2fac1?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'cmoreno',
#     'link': 'https://stackoverflow.com/users/13350535/cmoreno'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646224832,
#    'last_edit_date': 1646224832,
#    'creation_date': 1645833642,
#    'answer_id': 71272951,
#    'question_id': 57282520,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2145,
#     'user_id': 11335032,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d8a2395b2fa45d4aa621f4e6f500ede7?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'maxbachmann',
#     'link': 'https://stackoverflow.com/users/11335032/maxbachmann'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646224633,
#    'last_edit_date': 1646224633,
#    'creation_date': 1645530108,
#    'answer_id': 71220687,
#    'question_id': 71216091,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 36,
#     'user_id': 14327169,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgPe4dHSGdAodxbjSl8lk6MhBqeLbT86OQ1VV_7VA=k-s256',
#     'display_name': 'Hansen Marcelino Azali',
#     'link': 'https://stackoverflow.com/users/14327169/hansen-marcelino-azali'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646224104,
#    'last_edit_date': 1646224104,
#    'creation_date': 1645527174,
#    'answer_id': 71219971,
#    'question_id': 71216444,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 180,
#     'user_id': 10424004,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-tSCaZNGwhlM/AAAAAAAAAAI/AAAAAAAAAVI/Ah-qf-xFMak/photo.jpg?sz=256',
#     'display_name': 'Juranir Santos',
#     'link': 'https://stackoverflow.com/users/10424004/juranir-santos'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646223848,
#    'last_edit_date': 1646223848,
#    'creation_date': 1644434645,
#    'answer_id': 71055525,
#    'question_id': 71054761,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 18307933,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJxLspzVFgKokh3-snJjDX-FpB1ADMFPjyGJ4fQ-=k-s256',
#     'display_name': 'agni bahar',
#     'link': 'https://stackoverflow.com/users/18307933/agni-bahar'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646223686,
#    'last_edit_date': 1646223686,
#    'creation_date': 1645785931,
#    'answer_id': 71264645,
#    'question_id': 67202545,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 16630300,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gi6w8X56GclfWtLcrcvhlXxmTnGyPdkYHO33qqf=k-s256',
#     'display_name': 'CODE WRITER',
#     'link': 'https://stackoverflow.com/users/16630300/code-writer'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646223149,
#    'last_edit_date': 1646223149,
#    'creation_date': 1645806609,
#    'answer_id': 71268863,
#    'question_id': 46460127,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 165,
#     'user_id': 3987227,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/1517590078/picture?type=large',
#     'display_name': 'Xavier Junqu&#233;',
#     'link': 'https://stackoverflow.com/users/3987227/xavier-junqu%c3%a9'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646220420,
#    'last_edit_date': 1646220420,
#    'creation_date': 1645797571,
#    'answer_id': 71266969,
#    'question_id': 71264276,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1790,
#     'user_id': 17949945,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJzoi_MAUMokDZBPnkahcCuEDoFrhPtlycbVBKih=k-s256',
#     'display_name': 'Alexander Ivanchenko',
#     'link': 'https://stackoverflow.com/users/17949945/alexander-ivanchenko'},
#    'is_accepted': True,
#    'score': 4,
#    'last_activity_date': 1646219826,
#    'last_edit_date': 1646219826,
#    'creation_date': 1645750036,
#    'answer_id': 71259850,
#    'question_id': 71259746,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 30054,
#     'user_id': 8951377,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/2MYqI.jpg?s=256&g=1',
#     'display_name': 'ppotaczek',
#     'link': 'https://stackoverflow.com/users/8951377/ppotaczek'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646219579,
#    'last_edit_date': 1646219579,
#    'creation_date': 1645443083,
#    'answer_id': 71205590,
#    'question_id': 71197534,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 21,
#     'user_id': 15264739,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4dda12266199ab2ba239d98741fcc2a7?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Pink',
#     'link': 'https://stackoverflow.com/users/15264739/pink'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646218768,
#    'last_edit_date': 1646218768,
#    'creation_date': 1645787723,
#    'answer_id': 71265044,
#    'question_id': 71209524,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 117,
#     'user_id': 16391931,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/fa551fb5a267e56b16aa2e113be2e2a7?s=256&d=identicon&r=PG',
#     'display_name': 'Gismo1337',
#     'link': 'https://stackoverflow.com/users/16391931/gismo1337'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1646218588,
#    'last_edit_date': 1646218588,
#    'creation_date': 1645796952,
#    'answer_id': 71266841,
#    'question_id': 71266467,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 354,
#     'user_id': 14135840,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5cb3e9b6b028395555104e010808e889?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Codeman',
#     'link': 'https://stackoverflow.com/users/14135840/codeman'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646218347,
#    'last_edit_date': 1646218347,
#    'creation_date': 1644233623,
#    'answer_id': 71017872,
#    'question_id': 71017771,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 7033,
#     'user_id': 1103511,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/04abdf0c07cc47e38785951ce0393027?s=256&d=identicon&r=PG',
#     'display_name': 'fedonev',
#     'link': 'https://stackoverflow.com/users/1103511/fedonev'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646215477,
#    'last_edit_date': 1646215477,
#    'creation_date': 1645867748,
#    'answer_id': 71275487,
#    'question_id': 71274902,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5533,
#     'user_id': 1679286,
#     'user_type': 'registered',
#     'accept_rate': 80,
#     'profile_image': 'https://www.gravatar.com/avatar/68e12b1da713bc49ac140d8fdac4f518?s=256&d=identicon&r=PG',
#     'display_name': 'winner_joiner',
#     'link': 'https://stackoverflow.com/users/1679286/winner-joiner'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646214789,
#    'last_edit_date': 1646214789,
#    'creation_date': 1645075988,
#    'answer_id': 71152961,
#    'question_id': 71150858,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 19,
#     'user_id': 18175181,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/rfLJz.jpg?s=256&g=1',
#     'display_name': 'xtekky',
#     'link': 'https://stackoverflow.com/users/18175181/xtekky'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646214465,
#    'last_edit_date': 1646214465,
#    'creation_date': 1645002709,
#    'answer_id': 71138980,
#    'question_id': 71084080,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 12281554,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/Mx7PN.jpg?s=256&g=1',
#     'display_name': 'seine',
#     'link': 'https://stackoverflow.com/users/12281554/seine'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646213596,
#    'last_edit_date': 1646213596,
#    'creation_date': 1645957307,
#    'answer_id': 71283929,
#    'question_id': 71275642,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 66,
#     'user_id': 14476286,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/k8uQW.jpg?s=256&g=1',
#     'display_name': 'rs_punia',
#     'link': 'https://stackoverflow.com/users/14476286/rs-punia'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646213374,
#    'last_edit_date': 1646213374,
#    'creation_date': 1645369757,
#    'answer_id': 71195730,
#    'question_id': 71195180,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 517,
#     'user_id': 2254346,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/nAgE4.png?s=256&g=1',
#     'display_name': 'MakisH',
#     'link': 'https://stackoverflow.com/users/2254346/makish'},
#    'is_accepted': False,
#    'score': 4,
#    'last_activity_date': 1646212569,
#    'last_edit_date': 1646212569,
#    'creation_date': 1644281331,
#    'answer_id': 71027261,
#    'question_id': 64857370,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 11287846,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-4MIaQ1ozd0M/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rfCMtJQBzngHjWEOEsE5esD6mQIOQ/mo/photo.jpg?sz=256',
#     'display_name': 'G.TC',
#     'link': 'https://stackoverflow.com/users/11287846/g-tc'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646212033,
#    'last_edit_date': 1646212033,
#    'creation_date': 1645698094,
#    'answer_id': 71250436,
#    'question_id': 66625478,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1215,
#     'user_id': 15760624,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Ghic6cwAe_Ls-XhZ41KOlbmV_0-I6buy7hAYy8wyw=k-s256',
#     'display_name': 'Mushfirat Mohaimin',
#     'link': 'https://stackoverflow.com/users/15760624/mushfirat-mohaimin'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646211733,
#    'last_edit_date': 1646211733,
#    'creation_date': 1645888551,
#    'answer_id': 71277795,
#    'question_id': 71277632,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 98509,
#     'user_id': 651174,
#     'user_type': 'registered',
#     'accept_rate': 92,
#     'profile_image': 'https://www.gravatar.com/avatar/2e2d79b9350ef4ebf04ac0ad5816a5c3?s=256&d=identicon&r=PG',
#     'display_name': 'David542',
#     'link': 'https://stackoverflow.com/users/651174/david542'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646211465,
#    'last_edit_date': 1646211465,
#    'creation_date': 1644951607,
#    'answer_id': 71131940,
#    'question_id': 71131844,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5824,
#     'user_id': 6844481,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/9Z6GA.jpg?s=256&g=1',
#     'display_name': 'Shahar Shokrani',
#     'link': 'https://stackoverflow.com/users/6844481/shahar-shokrani'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646211130,
#    'last_edit_date': 1646211130,
#    'creation_date': 1644840561,
#    'answer_id': 71111693,
#    'question_id': 71095327,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 17180339,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gj-qNrHEuCDOJsKExOHbAiV50mYCvbgj5OHI_DPEw=k-s256',
#     'display_name': 'faceboook',
#     'link': 'https://stackoverflow.com/users/17180339/faceboook'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646210908,
#    'last_edit_date': 1646210908,
#    'creation_date': 1645711580,
#    'answer_id': 71253236,
#    'question_id': 71252670,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5928,
#     'user_id': 1017348,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://i.stack.imgur.com/rKrOK.jpg?s=256&g=1',
#     'display_name': 'Joachim W',
#     'link': 'https://stackoverflow.com/users/1017348/joachim-w'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1646210478,
#    'last_edit_date': 1646210478,
#    'creation_date': 1645811431,
#    'answer_id': 71269846,
#    'question_id': 8751109,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5392,
#     'user_id': 10699119,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/a7Bnl.jpg?s=256&g=1',
#     'display_name': 'Sana Ebadi',
#     'link': 'https://stackoverflow.com/users/10699119/sana-ebadi'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646209523,
#    'last_edit_date': 1646209523,
#    'creation_date': 1645480873,
#    'answer_id': 71213530,
#    'question_id': 71210925,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 373,
#     'user_id': 9907597,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-w7zV11Dz09c/AAAAAAAAAAI/AAAAAAAABnA/-WdwyhrccOk/photo.jpg?sz=256',
#     'display_name': 'Meer',
#     'link': 'https://stackoverflow.com/users/9907597/meer'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646209054,
#    'last_edit_date': 1646209054,
#    'creation_date': 1644946583,
#    'answer_id': 71130923,
#    'question_id': 9869051,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 516,
#     'user_id': 2693608,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/GoJAk.jpg?s=256&g=1',
#     'display_name': 'ezer',
#     'link': 'https://stackoverflow.com/users/2693608/ezer'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1646208913,
#    'last_edit_date': 1646208913,
#    'creation_date': 1645657744,
#    'answer_id': 71245102,
#    'question_id': 71157689,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 405,
#     'user_id': 12365093,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7534c4b5a61a06b18e8651435e6e951e?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'TheMisplacedMechEngineer',
#     'link': 'https://stackoverflow.com/users/12365093/themisplacedmechengineer'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646208737,
#    'last_edit_date': 1646208737,
#    'creation_date': 1645865125,
#    'answer_id': 71275244,
#    'question_id': 71275082,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 3297,
#     'user_id': 9108912,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/hkrze.jpg?s=256&g=1',
#     'display_name': 'Vaebhav',
#     'link': 'https://stackoverflow.com/users/9108912/vaebhav'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646208668,
#    'last_edit_date': 1646208668,
#    'creation_date': 1645973738,
#    'answer_id': 71285790,
#    'question_id': 71284126,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 12527,
#     'user_id': 6299857,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://i.stack.imgur.com/O4G3u.jpg?s=256&g=1',
#     'display_name': 'Prasad Telkikar',
#     'link': 'https://stackoverflow.com/users/6299857/prasad-telkikar'},
#    'is_accepted': True,
#    'score': 3,
#    'last_activity_date': 1646208194,
#    'last_edit_date': 1646208194,
#    'creation_date': 1645433164,
#    'answer_id': 71203412,
#    'question_id': 71203341,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 4263,
#     'user_id': 8172439,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/XmATK.jpg?s=256&g=1',
#     'display_name': 'Kai - Kazuya Ito',
#     'link': 'https://stackoverflow.com/users/8172439/kai-kazuya-ito'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1646208166,
#    'last_edit_date': 1646208166,
#    'creation_date': 1644205794,
#    'answer_id': 71013275,
#    'question_id': 70074459,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 18673,
#     'user_id': 5471709,
#     'user_type': 'registered',
#     'accept_rate': 64,
#     'profile_image': 'https://www.gravatar.com/avatar/f11ba6c2d97521a03a7b347f37ffa3f9?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Kenly',
#     'link': 'https://stackoverflow.com/users/5471709/kenly'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646207990,
#    'last_edit_date': 1646207990,
#    'creation_date': 1645357718,
#    'answer_id': 71194115,
#    'question_id': 71193714,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 18992,
#     'user_id': 4637585,
#     'user_type': 'registered',
#     'accept_rate': 95,
#     'profile_image': 'https://www.gravatar.com/avatar/2ff170e0cfa0be15efaabd3acef4df34?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Rolf of Saxony',
#     'link': 'https://stackoverflow.com/users/4637585/rolf-of-saxony'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646207813,
#    'last_edit_date': 1646207813,
#    'creation_date': 1645876262,
#    'answer_id': 71276390,
#    'question_id': 71270582,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 665,
#     'user_id': 17873304,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/VSesY.jpg?s=256&g=1',
#     'display_name': 'medilies',
#     'link': 'https://stackoverflow.com/users/17873304/medilies'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646207784,
#    'last_edit_date': 1646207784,
#    'creation_date': 1645809456,
#    'answer_id': 71269421,
#    'question_id': 71265220,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 426,
#     'user_id': 2547506,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/DmqGG.jpg?s=256&g=1',
#     'display_name': 'Brugere',
#     'link': 'https://stackoverflow.com/users/2547506/brugere'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646207418,
#    'last_edit_date': 1646207418,
#    'creation_date': 1644347334,
#    'answer_id': 71039546,
#    'question_id': 70930972,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 5383996,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6f3a85fe827bb4a1ffd25dfc40be6baf?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Ashiq Ali',
#     'link': 'https://stackoverflow.com/users/5383996/ashiq-ali'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646207414,
#    'last_edit_date': 1646207414,
#    'creation_date': 1645732479,
#    'answer_id': 71257539,
#    'question_id': 48732441,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 10612646,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-l-zeZiDLD8g/AAAAAAAAAAI/AAAAAAAAAFA/uOHffXY82bI/photo.jpg?sz=256',
#     'display_name': 'mjfakhr',
#     'link': 'https://stackoverflow.com/users/10612646/mjfakhr'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646207362,
#    'last_edit_date': 1646207362,
#    'creation_date': 1645849817,
#    'answer_id': 71274085,
#    'question_id': 27066873,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 442,
#     'user_id': 17939455,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8c204a70875cbdf5271c124fc7f13a21?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Darth-CodeX',
#     'link': 'https://stackoverflow.com/users/17939455/darth-codex'},
#    'is_accepted': False,
#    'score': 4,
#    'last_activity_date': 1646207353,
#    'last_edit_date': 1646207353,
#    'creation_date': 1644847904,
#    'answer_id': 71113261,
#    'question_id': 71112750,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 6275263,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-oslbAoaMmzo/AAAAAAAAAAI/AAAAAAAAArQ/LFZFT5GsbjM/photo.jpg?sz=256',
#     'display_name': 'jean tchietcheu',
#     'link': 'https://stackoverflow.com/users/6275263/jean-tchietcheu'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646207273,
#    'last_edit_date': 1646207273,
#    'creation_date': 1645717590,
#    'answer_id': 71254653,
#    'question_id': 52787636,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 18299472,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJysbeZ2mVvob5VlaiL6vdXrzdKnKh1Tbw0S-uo2QQ=k-s256',
#     'display_name': 'RkR10',
#     'link': 'https://stackoverflow.com/users/18299472/rkr10'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646207211,
#    'last_edit_date': 1646207211,
#    'creation_date': 1645709150,
#    'answer_id': 71252720,
#    'question_id': 65982880,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 23,
#     'user_id': 1374314,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/44a44add5d508fe9e6c2149b01e15ed2?s=256&d=identicon&r=PG',
#     'display_name': 'XIA YUN',
#     'link': 'https://stackoverflow.com/users/1374314/xia-yun'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646207175,
#    'last_edit_date': 1646207175,
#    'creation_date': 1645703332,
#    'answer_id': 71251492,
#    'question_id': 66355496,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 376,
#     'user_id': 10202496,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/37abaf74f1f640a8ccd9021ef464081d?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'iabughosh',
#     'link': 'https://stackoverflow.com/users/10202496/iabughosh'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646203206,
#    'last_edit_date': 1646203206,
#    'creation_date': 1645910658,
#    'answer_id': 71280391,
#    'question_id': 71275788,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 6880,
#     'user_id': 6184972,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/cc777654a07ef22d2d17475922cd1af6?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Steve',
#     'link': 'https://stackoverflow.com/users/6184972/steve'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646202925,
#    'last_edit_date': 1646202925,
#    'creation_date': 1645812541,
#    'answer_id': 71270042,
#    'question_id': 27177661,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 55,
#     'user_id': 4688890,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f8df2cf2a8f497740983f68d6847b1de?s=256&d=identicon&r=PG',
#     'display_name': 'Sid Mathur',
#     'link': 'https://stackoverflow.com/users/4688890/sid-mathur'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646202693,
#    'last_edit_date': 1646202693,
#    'creation_date': 1645896740,
#    'answer_id': 71278873,
#    'question_id': 71233578,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 22276,
#     'user_id': 6877799,
#     'user_type': 'registered',
#     'accept_rate': 75,
#     'profile_image': 'https://i.stack.imgur.com/hdkcM.png?s=256&g=1',
#     'display_name': 'AmerllicA',
#     'link': 'https://stackoverflow.com/users/6877799/amerllica'},
#    'is_accepted': True,
#    'score': 4,
#    'last_activity_date': 1646202480,
#    'last_edit_date': 1646202480,
#    'creation_date': 1645986644,
#    'answer_id': 71287468,
#    'question_id': 71287360,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1335,
#     'user_id': 2578125,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/2fc1e7a46b2969bca62390b3b828b8cb?s=256&d=identicon&r=PG',
#     'display_name': 'OXiGEN',
#     'link': 'https://stackoverflow.com/users/2578125/oxigen'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646202034,
#    'last_edit_date': 1646202034,
#    'creation_date': 1645400239,
#    'answer_id': 71199736,
#    'question_id': 16613809,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 38823,
#     'user_id': 3000206,
#     'user_type': 'registered',
#     'accept_rate': 98,
#     'profile_image': 'https://i.stack.imgur.com/BK1fo.jpg?s=256&g=1',
#     'display_name': 'Carcigenicate',
#     'link': 'https://stackoverflow.com/users/3000206/carcigenicate'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1646199580,
#    'last_edit_date': 1646199580,
#    'creation_date': 1643916053,
#    'answer_id': 70977094,
#    'question_id': 70976660,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 8478,
#     'user_id': 11450820,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/120cc149a72c2f49f8a2e28202271f1a?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'j1-lee',
#     'link': 'https://stackoverflow.com/users/11450820/j1-lee'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1646198728,
#    'last_edit_date': 1646198728,
#    'creation_date': 1645942809,
#    'answer_id': 71282600,
#    'question_id': 71281098,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 16741527,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GiQ2skp4DlrrgZpH2lxq2aEY96RtrWgjT1-Ffkwmg=k-s256',
#     'display_name': 'Bhargav Dobariya',
#     'link': 'https://stackoverflow.com/users/16741527/bhargav-dobariya'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646197550,
#    'last_edit_date': 1646197550,
#    'creation_date': 1645718192,
#    'answer_id': 71254786,
#    'question_id': 65275297,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 24,
#     'user_id': 18265638,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJytNunrYsT8VBh8nDaNOPyv02aaSt8m5G3zA291=k-s256',
#     'display_name': 'Sathi Aiswarya',
#     'link': 'https://stackoverflow.com/users/18265638/sathi-aiswarya'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646196718,
#    'last_edit_date': 1646196718,
#    'creation_date': 1645726492,
#    'answer_id': 71256468,
#    'question_id': 71256222,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 24,
#     'user_id': 18265638,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJytNunrYsT8VBh8nDaNOPyv02aaSt8m5G3zA291=k-s256',
#     'display_name': 'Sathi Aiswarya',
#     'link': 'https://stackoverflow.com/users/18265638/sathi-aiswarya'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646196602,
#    'last_edit_date': 1646196602,
#    'creation_date': 1645549304,
#    'answer_id': 71225355,
#    'question_id': 71223542,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2568,
#     'user_id': 8508004,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/798dcbaee1ba2df492410d761941c87b?s=256&d=identicon&r=PG',
#     'display_name': 'Wayne',
#     'link': 'https://stackoverflow.com/users/8508004/wayne'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646193956,
#    'last_edit_date': 1646193956,
#    'creation_date': 1645990727,
#    'answer_id': 71287923,
#    'question_id': 71285381,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 9133487,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/84ae651602fd0e247a7ce9ff077ba631?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Duong',
#     'link': 'https://stackoverflow.com/users/9133487/duong'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646193103,
#    'last_edit_date': 1646193103,
#    'creation_date': 1645784272,
#    'answer_id': 71264327,
#    'question_id': 54230426,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 8214,
#     'user_id': 15545927,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/c7T8j.jpg?s=256&g=1',
#     'display_name': 'Anoop Rana',
#     'link': 'https://stackoverflow.com/users/15545927/anoop-rana'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1646192347,
#    'last_edit_date': 1646192347,
#    'creation_date': 1645807052,
#    'answer_id': 71268958,
#    'question_id': 71268078,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 21649,
#     'user_id': 1978251,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/73f7dd539ad8ec8372af0d06e4f76939?s=256&d=identicon&r=PG',
#     'display_name': 'engineersmnky',
#     'link': 'https://stackoverflow.com/users/1978251/engineersmnky'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646189647,
#    'last_edit_date': 1646189647,
#    'creation_date': 1644717726,
#    'answer_id': 71097342,
#    'question_id': 71089467,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 18508,
#     'user_id': 4175750,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/99b9dcc927d69a760e7025e097e6bf32?s=256&d=identicon&r=PG',
#     'display_name': 'Croises',
#     'link': 'https://stackoverflow.com/users/4175750/croises'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646189389,
#    'last_edit_date': 1646189389,
#    'creation_date': 1645584277,
#    'answer_id': 71230783,
#    'question_id': 71229501,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 6236,
#     'user_id': 954643,
#     'user_type': 'registered',
#     'accept_rate': 80,
#     'profile_image': 'https://www.gravatar.com/avatar/4179aad8a57c39de31d8ef12a9bf7e84?s=256&d=identicon&r=PG',
#     'display_name': 'qix',
#     'link': 'https://stackoverflow.com/users/954643/qix'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646186788,
#    'last_edit_date': 1646186788,
#    'creation_date': 1645781091,
#    'answer_id': 71263670,
#    'question_id': 70277515,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1013,
#     'user_id': 16764901,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/XpnL5.jpg?s=256&g=1',
#     'display_name': 'Jiale Xue - MSFT',
#     'link': 'https://stackoverflow.com/users/16764901/jiale-xue-msft'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646186544,
#    'last_edit_date': 1646186544,
#    'creation_date': 1645695183,
#    'answer_id': 71249832,
#    'question_id': 71249552,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1247,
#     'user_id': 7013896,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/yqmJz.jpg?s=256&g=1',
#     'display_name': 'Sweepy Dodo',
#     'link': 'https://stackoverflow.com/users/7013896/sweepy-dodo'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646184610,
#    'last_edit_date': 1646184610,
#    'creation_date': 1644362483,
#    'answer_id': 71042150,
#    'question_id': 71040588,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 18280158,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7d1fac34d3f9a3f40b560b352220fcd9?s=256&d=identicon&r=PG',
#     'display_name': 'chok120',
#     'link': 'https://stackoverflow.com/users/18280158/chok120'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1646181720,
#    'last_edit_date': 1646181720,
#    'creation_date': 1645544950,
#    'answer_id': 71224265,
#    'question_id': 47269368,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 399,
#     'user_id': 4854821,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/9d030493e2408cefa462f69e2e5f6383?s=256&d=identicon&r=PG',
#     'display_name': 'yut23',
#     'link': 'https://stackoverflow.com/users/4854821/yut23'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646181539,
#    'last_edit_date': 1646181539,
#    'creation_date': 1645674481,
#    'answer_id': 71246874,
#    'question_id': 71246223,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1050,
#     'user_id': 1378243,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d6ba31ef6b469e5e8b11d6f4f33fd86e?s=256&d=identicon&r=PG',
#     'display_name': 'CodeLurker',
#     'link': 'https://stackoverflow.com/users/1378243/codelurker'},
#    'is_accepted': False,
#    'score': 3,
#    'last_activity_date': 1646181269,
#    'last_edit_date': 1646181269,
#    'creation_date': 1644197362,
#    'answer_id': 71012589,
#    'question_id': 71012325,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 171,
#     'user_id': 9488192,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/3UZUm.jpg?s=256&g=1',
#     'display_name': 'Mithun Rana',
#     'link': 'https://stackoverflow.com/users/9488192/mithun-rana'},
#    'is_accepted': False,
#    'score': 15,
#    'last_activity_date': 1646181105,
#    'last_edit_date': 1646181105,
#    'creation_date': 1643751233,
#    'answer_id': 70947829,
#    'question_id': 2432764,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 11,
#     'user_id': 7999868,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7205f7ca1057f67e3de21497da02f36b?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'RamaT',
#     'link': 'https://stackoverflow.com/users/7999868/ramat'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646179138,
#    'last_edit_date': 1646179138,
#    'creation_date': 1645229207,
#    'answer_id': 71181199,
#    'question_id': 69123156,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 133001,
#     'user_id': 478884,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/rLckc.jpg?s=256&g=1',
#     'display_name': 'Tim Williams',
#     'link': 'https://stackoverflow.com/users/478884/tim-williams'},
#    'is_accepted': False,
#    'score': 3,
#    'last_activity_date': 1646179079,
#    'last_edit_date': 1646179079,
#    'creation_date': 1646006356,
#    'answer_id': 71289404,
#    'question_id': 71289108,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1012,
#     'user_id': 4673851,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-KB3AubWijUc/AAAAAAAAAAI/AAAAAAAAADg/u1QF97yIFWs/photo.jpg?sz=256',
#     'display_name': 'sajjad rezaei',
#     'link': 'https://stackoverflow.com/users/4673851/sajjad-rezaei'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1646178798,
#    'last_edit_date': 1646178798,
#    'creation_date': 1646001446,
#    'answer_id': 71289014,
#    'question_id': 71288797,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 81,
#     'user_id': 770409,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/Tro3D.png?s=256&g=1',
#     'display_name': 'Goulart',
#     'link': 'https://stackoverflow.com/users/770409/goulart'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646177658,
#    'last_edit_date': 1646177658,
#    'creation_date': 1645575227,
#    'answer_id': 71229900,
#    'question_id': 47051867,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 11,
#     'user_id': 12888451,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-IK8qcj8_Zys/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rd29aqGhXsv3FDFxTe1ciddnR6O_A/photo.jpg?sz=256',
#     'display_name': 'Peker Celik',
#     'link': 'https://stackoverflow.com/users/12888451/peker-celik'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646175971,
#    'last_edit_date': 1646175971,
#    'creation_date': 1644253774,
#    'answer_id': 71022517,
#    'question_id': 71022445,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 61,
#     'user_id': 5293758,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-MT3IADsfRDU/AAAAAAAAAAI/AAAAAAAAABc/DpD1BXvBCgM/photo.jpg?sz=256',
#     'display_name': 'Eng.Faris Alsmawi',
#     'link': 'https://stackoverflow.com/users/5293758/eng-faris-alsmawi'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646175859,
#    'last_edit_date': 1646175859,
#    'creation_date': 1645923501,
#    'answer_id': 71281369,
#    'question_id': 71216815,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 12315279,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-ta7thSPeA8c/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rfaWNOvO4-bz0dFnoUiOBshX5RIAA/photo.jpg?sz=256',
#     'display_name': 'Mena Nashaat',
#     'link': 'https://stackoverflow.com/users/12315279/mena-nashaat'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646175305,
#    'last_edit_date': 1646175305,
#    'creation_date': 1645891305,
#    'answer_id': 71278165,
#    'question_id': 57544749,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 57,
#     'user_id': 11390952,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/4w7q6.jpg?s=256&g=1',
#     'display_name': 'İsa Diliballı',
#     'link': 'https://stackoverflow.com/users/11390952/%c4%b0sa-diliball%c4%b1'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646175179,
#    'last_edit_date': 1646175179,
#    'creation_date': 1645200291,
#    'answer_id': 71176487,
#    'question_id': 71172297,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 11,
#     'user_id': 16196761,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJytVfAQLQlk2brifLc6oSyZySIQ0X_V-o2p3qML=k-s256',
#     'display_name': 'Moez Elahi',
#     'link': 'https://stackoverflow.com/users/16196761/moez-elahi'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646175049,
#    'last_edit_date': 1646175049,
#    'creation_date': 1645799149,
#    'answer_id': 71267293,
#    'question_id': 71236198,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 3698,
#     'user_id': 15407542,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/da05d1b0f0f893a880e372cc14592605?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Mikołaj Głodziak',
#     'link': 'https://stackoverflow.com/users/15407542/miko%c5%82aj-g%c5%82odziak'},
#    'is_accepted': False,
#    'community_owned_date': 1645791254,
#    'score': 1,
#    'last_activity_date': 1646174848,
#    'last_edit_date': 1646174848,
#    'creation_date': 1645791254,
#    'answer_id': 71265708,
#    'question_id': 71261707,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 5403261,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8d52298f5ba2a447e7aea256e402266f?s=256&d=identicon&r=PG',
#     'display_name': 'kavitha',
#     'link': 'https://stackoverflow.com/users/5403261/kavitha'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646174727,
#    'last_edit_date': 1646174727,
#    'creation_date': 1645768886,
#    'answer_id': 71261689,
#    'question_id': 71109046,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 9996,
#     'user_id': 1197045,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bc014d2173a1a5ea2c0417712ced8ff0?s=256&d=identicon&r=PG',
#     'display_name': 'Ignazio',
#     'link': 'https://stackoverflow.com/users/1197045/ignazio'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646173873,
#    'last_edit_date': 1646173873,
#    'creation_date': 1645988054,
#    'answer_id': 71287617,
#    'question_id': 71278773,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 27466,
#     'user_id': 1552534,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/uAEcW.jpg?s=256&g=1',
#     'display_name': 'WJS',
# ...
#     'display_name': 'Michal Trojanowski',
#     'link': 'https://stackoverflow.com/users/1712294/michal-trojanowski'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1646041599,
#    'last_edit_date': 1646041599,
#    'creation_date': 1645519858,
#    'answer_id': 71218337,
#    'question_id': 71157491,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 12779369,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/188792ddbf1c930229fd40b66fc4bee7?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'bugdruhman',
#     'link': 'https://stackoverflow.com/users/12779369/bugdruhman'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646041287,
#    'last_edit_date': 1646041287,
#    'creation_date': 1644576294,
#    'answer_id': 71078797,
#    'question_id': 69308388,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 481224,
#     'user_id': 209103,
#     'user_type': 'registered',
#     'accept_rate': 73,
#     'profile_image': 'https://www.gravatar.com/avatar/12d378e6a9788ab9c94bbafe242b82b4?s=256&d=identicon&r=PG',
#     'display_name': 'Frank van Puffelen',
#     'link': 'https://stackoverflow.com/users/209103/frank-van-puffelen'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646041004,
#    'last_edit_date': 1646041004,
#    'creation_date': 1645976663,
#    'answer_id': 71286158,
#    'question_id': 71285613,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1325,
#     'user_id': 2649154,
#     'user_type': 'registered',
#     'accept_rate': 93,
#     'profile_image': 'https://www.gravatar.com/avatar/1b459523f6b56a15ecdba17640b576ce?s=256&d=identicon&r=PG',
#     'display_name': 'gioravered',
#     'link': 'https://stackoverflow.com/users/2649154/gioravered'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646040940,
#    'last_edit_date': 1646040940,
#    'creation_date': 1645949204,
#    'answer_id': 71283122,
#    'question_id': 71282813,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5753,
#     'user_id': 5342297,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ec65b3838b1d1ea981cdb5be0a7a4a57?s=256&d=identicon&r=PG',
#     'display_name': 'Siliarus',
#     'link': 'https://stackoverflow.com/users/5342297/siliarus'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646040933,
#    'last_edit_date': 1646040933,
#    'creation_date': 1645696785,
#    'answer_id': 71250186,
#    'question_id': 71242104,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2903,
#     'user_id': 17218429,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/19da41c6beb0b9bfd2b9e311d9ce69ab?s=256&d=identicon&r=PG',
#     'display_name': 'lukas.j',
#     'link': 'https://stackoverflow.com/users/17218429/lukas-j'},
#    'is_accepted': False,
#    'score': 4,
#    'last_activity_date': 1646040760,
#    'last_edit_date': 1646040760,
#    'creation_date': 1645963604,
#    'answer_id': 71284615,
#    'question_id': 71284191,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1869,
#     'user_id': 10879061,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/dd339757af5995ab15d4f5759b270fc2?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Rob Lambden',
#     'link': 'https://stackoverflow.com/users/10879061/rob-lambden'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1646040752,
#    'last_edit_date': 1646040752,
#    'creation_date': 1645983367,
#    'answer_id': 71287028,
#    'question_id': 71284309,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1120,
#     'user_id': 4036754,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/dfb06bb3b7c7f4c276bdb85cfae93a63?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Violeta Georgieva',
#     'link': 'https://stackoverflow.com/users/4036754/violeta-georgieva'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646040593,
#    'last_edit_date': 1646040593,
#    'creation_date': 1645710569,
#    'answer_id': 71252998,
#    'question_id': 71235334,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 164443,
#     'user_id': 2836621,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/suHg4.jpg?s=256&g=1',
#     'display_name': 'Mark Setchell',
#     'link': 'https://stackoverflow.com/users/2836621/mark-setchell'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646040372,
#    'last_edit_date': 1646040372,
#    'creation_date': 1645898820,
#    'answer_id': 71279143,
#    'question_id': 71279087,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 162828,
#     'user_id': 850848,
#     'user_type': 'registered',
#     'accept_rate': 80,
#     'profile_image': 'https://www.gravatar.com/avatar/c287735beca76400cb9b6d08bf591cb9?s=256&d=identicon&r=PG',
#     'display_name': 'Martin Prikryl',
#     'link': 'https://stackoverflow.com/users/850848/martin-prikryl'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646040364,
#    'last_edit_date': 1646040364,
#    'creation_date': 1645738928,
#    'answer_id': 71258609,
#    'question_id': 71253538,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 271,
#     'user_id': 4750974,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-TqQ1WHSwbac/AAAAAAAAAAI/AAAAAAAAABk/3OFXqmH9iFo/photo.jpg?sz=256',
#     'display_name': 'eexpress',
#     'link': 'https://stackoverflow.com/users/4750974/eexpress'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646040021,
#    'last_edit_date': 1646040021,
#    'creation_date': 1645174350,
#    'answer_id': 71170696,
#    'question_id': 66319723,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 98735,
#     'user_id': 861716,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/cb1a28030a6da0e72693e36c77eb3cd6?s=256&d=identicon&r=PG',
#     'display_name': 'Gert Arnold',
#     'link': 'https://stackoverflow.com/users/861716/gert-arnold'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1646039864,
#    'last_edit_date': 1646039864,
#    'creation_date': 1645126341,
#    'answer_id': 71164332,
#    'question_id': 71156526,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 6361,
#     'user_id': 1305947,
#     'user_type': 'registered',
#     'accept_rate': 81,
#     'profile_image': 'https://i.stack.imgur.com/iV3u1.jpg?s=256&g=1',
#     'display_name': 'Joel G Mathew',
#     'link': 'https://stackoverflow.com/users/1305947/joel-g-mathew'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646039406,
#    'last_edit_date': 1646039406,
#    'creation_date': 1644994536,
#    'answer_id': 71137474,
#    'question_id': 71094346,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 131,
#     'user_id': 15235787,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8ab172a1d26340476009a279ddf9eb75?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Johannes Schneider',
#     'link': 'https://stackoverflow.com/users/15235787/johannes-schneider'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646039214,
#    'last_edit_date': 1646039214,
#    'creation_date': 1645427370,
#    'answer_id': 71202394,
#    'question_id': 71180569,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 18298014,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Ght2gJHABE4IHHv7gEjmnItkJP3yQo5rsI2-Xs-=k-s256',
#     'display_name': 'Mariusz Wojcik',
#     'link': 'https://stackoverflow.com/users/18298014/mariusz-wojcik'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646039174,
#    'last_edit_date': 1646039174,
#    'creation_date': 1645697710,
#    'answer_id': 71250365,
#    'question_id': 71227567,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 216,
#     'user_id': 13419206,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/2931342913579230/picture?type=large',
#     'display_name': 'Edoardo Berardo',
#     'link': 'https://stackoverflow.com/users/13419206/edoardo-berardo'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646039131,
#    'last_edit_date': 1646039131,
#    'creation_date': 1645658854,
#    'answer_id': 71245234,
#    'question_id': 71245133,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 109,
#     'user_id': 13214342,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/85affbe31910e71cc250699f7a5e2f4b?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'liiiiiin',
#     'link': 'https://stackoverflow.com/users/13214342/liiiiiin'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1646038652,
#    'last_edit_date': 1646038652,
#    'creation_date': 1645998768,
#    'answer_id': 71288748,
#    'question_id': 71287051,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 306,
#     'user_id': 7302462,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/00286f701ffb4b0cf02d8f6ee3fdceac?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'deristnochda',
#     'link': 'https://stackoverflow.com/users/7302462/deristnochda'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646038332,
#    'last_edit_date': 1646038332,
#    'creation_date': 1645792295,
#    'answer_id': 71265915,
#    'question_id': 71258718,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 3,
#     'user_id': 15831839,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgykCEK_kGwSuD_TOI7whurX5FGFU0yR4QbnMErsQ=k-s256',
#     'display_name': 'RAJU KUMAR',
#     'link': 'https://stackoverflow.com/users/15831839/raju-kumar'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646038190,
#    'last_edit_date': 1646038190,
#    'creation_date': 1645989598,
#    'answer_id': 71287789,
#    'question_id': 71287426,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 17803205,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a9cb09dc3be5bffc85114b10eaf7be06?s=256&d=identicon&r=PG',
#     'display_name': 'Kacper Stasica',
#     'link': 'https://stackoverflow.com/users/17803205/kacper-stasica'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646038039,
#    'last_edit_date': 1646038039,
#    'creation_date': 1645799387,
#    'answer_id': 71267344,
#    'question_id': 61385852,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 3540,
#     'user_id': 3566606,
#     'user_type': 'registered',
#     'accept_rate': 70,
#     'profile_image': 'https://i.stack.imgur.com/B36KF.jpg?s=256&g=1',
#     'display_name': 'jonathan.scholbach',
#     'link': 'https://stackoverflow.com/users/3566606/jonathan-scholbach'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646037958,
#    'last_edit_date': 1646037958,
#    'creation_date': 1645593416,
#    'answer_id': 71231688,
#    'question_id': 71231687,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 14564,
#     'user_id': 8682983,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a6dbff0f3ccb0d71e217df94e38ea3c3?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'LeeLenalee',
#     'link': 'https://stackoverflow.com/users/8682983/leelenalee'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1646037896,
#    'last_edit_date': 1646037896,
#    'creation_date': 1645960284,
#    'answer_id': 71284250,
#    'question_id': 71283327,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 8004,
#     'user_id': 15019380,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/vG8j8.jpg?s=256&g=1',
#     'display_name': 'Mike Steelson',
#     'link': 'https://stackoverflow.com/users/15019380/mike-steelson'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646037794,
#    'last_edit_date': 1646037794,
#    'creation_date': 1645868167,
#    'answer_id': 71275544,
#    'question_id': 71274935,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1683,
#     'user_id': 612704,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/3ea79a7a80e058e4bf85a0d4bab62bda?s=256&d=identicon&r=PG',
#     'display_name': 'Steven',
#     'link': 'https://stackoverflow.com/users/612704/steven'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646037601,
#    'last_edit_date': 1646037601,
#    'creation_date': 1645085338,
#    'answer_id': 71154437,
#    'question_id': 31630822,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5516,
#     'user_id': 14311263,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/6GaBJ.png?s=256&g=1',
#     'display_name': 'Timus',
#     'link': 'https://stackoverflow.com/users/14311263/timus'},
#    'is_accepted': True,
#    'score': 3,
#    'last_activity_date': 1646037466,
#    'last_edit_date': 1646037466,
#    'creation_date': 1645905043,
#    'answer_id': 71279827,
#    'question_id': 71275142,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 55,
#     'user_id': 12719929,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/10dd326a9f873aecfbbde742db7d6536?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'FuzzyBall',
#     'link': 'https://stackoverflow.com/users/12719929/fuzzyball'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646037424,
#    'last_edit_date': 1646037424,
#    'creation_date': 1646001656,
#    'answer_id': 71289031,
#    'question_id': 71285115,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1046,
#     'user_id': 13830075,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d41b42e12e5a72e76b75b821d4de7900?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Ergis',
#     'link': 'https://stackoverflow.com/users/13830075/ergis'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1646037229,
#    'last_edit_date': 1646037229,
#    'creation_date': 1645698526,
#    'answer_id': 71250534,
#    'question_id': 71250442,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 19865,
#     'user_id': 3702377,
#     'user_type': 'registered',
#     'accept_rate': 90,
#     'profile_image': 'https://i.stack.imgur.com/Ac4wz.jpg?s=256&g=1',
#     'display_name': 'Benyamin Jafari',
#     'link': 'https://stackoverflow.com/users/3702377/benyamin-jafari'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646036905,
#    'last_edit_date': 1646036905,
#    'creation_date': 1645964827,
#    'answer_id': 71284745,
#    'question_id': 41620595,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 502,
#     'user_id': 12250254,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4f4803d1b5de25516cd4a60ef146b6ec?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'arhacktect',
#     'link': 'https://stackoverflow.com/users/12250254/arhacktect'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646036845,
#    'last_edit_date': 1646036845,
#    'creation_date': 1645573694,
#    'answer_id': 71229725,
#    'question_id': 18111657,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 11,
#     'user_id': 18068228,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJyMbTogoS4SxRZJYvZAQPQ6TRK7ZYt6uxF84M8l=k-s256',
#     'display_name': 'Zee',
#     'link': 'https://stackoverflow.com/users/18068228/zee'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1646036798,
#    'last_edit_date': 1646036798,
#    'creation_date': 1645998601,
#    'answer_id': 71288730,
#    'question_id': 69556591,
#    'content_license': 'CC BY-SA 4.0'}]}

# %% [markdown]
# Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=datetime(2022,3,2), min=5, tagged='python', sort='votes')
questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 261,
#  'total': 0,
#  'items': []}

# %% [markdown]
# Question 3: Find the answers with id 6784 and 6473.

# %%
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', ids=[6784, 6473])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 267,
#  'total': 0,
#  'items': [{'owner': {'reputation': 30059,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=256&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}
