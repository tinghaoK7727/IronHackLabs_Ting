# %%
import json
import pandas as pd

# %%
import requests
import numpy as np

# %%
response = requests.get('https://xkcd.com/')
response.status_code
# Out:
# 200

# %%
# challenge 1
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '3059', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Tue, 01 Mar 2022 02:27:55 GMT', 'ETag': 'W/"621d84ab-1e79"', 'Expires': 'Tue, 01 Mar 2022 07:29:47 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Tue, 01 Mar 2022 15:58:00 GMT', 'Age': '130', 'X-Served-By': 'cache-dfw18663-DFW, cache-cdg20752-CDG', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '2, 1', 'X-Timer': 'S1646150281.779290,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
response.headers['Expires']
# Out:
# 'Tue, 01 Mar 2022 07:29:47 GMT'

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: For the Sake of Simplicity</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script>\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="For the Sake of Simplicity">\n<meta property="og:url" content="https://xkcd.com/2587/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/for_the_sake_of_simplicity_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<div id="topContainer">\n<div id="topLeft">\n<ul>\n<li><a href="/archive">Archive</a></li>\n<li><a href="https://what-if.xkcd.com">What If?</a></li>\n<li><a href="https://blag.xkcd.com">Blag</a></li>\n<li><a rel="author" href="/about">About</a></li>\n<li><a href="/atom.xml">Feed</a>&bull;<a href="/newsletter/">Email</a></li>\n<li><a href="https://twitter.com/xkcd/">TW</a>&bull;<a href="https://www.facebook.com/TheXKCD/">FB</a>&bull;<a href="https://www.instagram.com/xkcd/">IG</a></li>\n<li><a href="/books/">-Books-</a></li>\n<li><a href="/what-if-2/">What If? 2</a></li>\n<li><a href="/what-if/">WI?</a>&bull;<a href="/thing-explainer/">TE</a>&bull;<a href="/how-to/">HT</a></li>\n</ul>\n</div>\n<div id="topRight">\n<div id="masthead">\n<span><a href="/"><img src="/s/0b7742.png" alt="xkcd.com logo" height="83" width="185"/></a></span>\n<span id="slogan">A webcomic of romance,<br/> sarcasm, math, and language.</span>\n</div>\n<div id="news">\n<div id="countdown" style="float: right; margin-right: 25px; width: 160px; height: 100px; position: relative;"><a style="display: flex;" href="https://xkcd.com/what-if-2/"><img alt="" style="width: 160px; height: 100px;" src="https://xkcd.com/s/5bef6b.png"><span style="position: absolute; left: 50%; top: 50%; transform: translate(-50%, -50%); padding: 0px 8px; color: black; font-family: xkcd-Regular-v3; font-size: 20px; font-variant: small-caps; letter-spacing: 1px; white-space: nowrap; background: white none repeat scroll 0% 0%; border-radius: 99px; display: none;"></span></a></div>\n<em>What If? 2: Additional Serious Scientific Answers to Absurd Hypothetical Questions</em> comes out 9/13. Preorder <a href="https://xkcd.com/what-if-2">here!</a>\n\n</div>\n</div>\n<div id="bgLeft" class="bg box"></div>\n<div id="bgRight" class="bg box"></div>\n</div>\n<div id="middleContainer" class="box">\n\n<div id="ctitle">For the Sake of Simplicity</div>\n<ul class="comicNav">\n<li><a href="/1/">|&lt;</a></li>\n<li><a rel="prev" href="/2586/" accesskey="p">&lt; Prev</a></li>\n<li><a href="//c.xkcd.com/random/comic/">Random</a></li>\n<li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>\n<li><a href="/">&gt;|</a></li>\n</ul>\n<div id="comic">\n<img src="//imgs.xkcd.com/comics/for_the_sake_of_simplicity.png" title="For the sake of simplicity, gardeners are assumed to move through Euclidean space--neglecting the distortion from general relativity--unless they are in the vicinity of a Schwarzschild Orchid." alt="For the Sake of Simplicity" srcset="//imgs.xkcd.com/comics/for_the_sake_of_simplicity_2x.png 2x" style="image-orientation:none" />\n</div>\n<ul class="comicNav">\n<li><a href="/1/">|&lt;</a></li>\n<li><a rel="prev" href="/2586/" accesskey="p">&lt; Prev</a></li>\n<li><a href="//c.xkcd.com/random/comic/">Random</a></li>\n<li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>\n<li><a href="/">&gt;|</a></li>\n</ul>\n<br />\nPermanent link to this comic: <a href="https://xkcd.com/2587">https://xkcd.com/2587 ...

# %%
# Get it via API
receive = requests.get('https://imgs.xkcd.com/comics/self_description.png')
with open (r'/Users/tinghaokao/Desktop/Photo_file/image.png', 'wb') as f:
    f.write(receive.content)

# %%
# challenge 2
ploads = requests.get('https://httpbin.org/get')
ploads
print(ploads.text)
print(ploads.url)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-621e4289-5597adea5f47771b2de65168"
#   },
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/get"
# }
#
# https://httpbin.org/get

# %%
# get information from the website => use 'get'
ploads = {'things': 2, 'total': 25}
ploads = requests.get('https://httpbin.org/get', params = ploads)
ploads.text
# Out:
# '{\n  "args": {\n    "things": "2", \n    "total": "25"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.27.1", \n    "X-Amzn-Trace-Id": "Root=1-621e4289-24f8077542b6ec63166d4a4a"\n  }, \n  "origin": "195.134.167.217", \n  "url": "https://httpbin.org/get?things=2&total=25"\n}\n'

# %%
ploads = {'Username': 'name', 'Password': 'adm'}
r = requests.post('https://httpbin.org/post', data = ploads)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "Password": "adm",
#     "Username": "name"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "26",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-621e428a-4e5d4fe9170cd2403a8b2eac"
#   },
#   "json": null,
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/post"
# }

# %%
ploads = {'Username': 'name', 'Password': 'adm'}
r_dict = r.json() # makes it show as a dictionary
print(r_dict)
print(r_dict['form'])
# Out:
# {'args': {}, 'data': '', 'files': {}, 'form': {'Password': 'adm', 'Username': 'name'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br', 'Content-Length': '26', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.27.1', 'X-Amzn-Trace-Id': 'Root=1-621e428a-4e5d4fe9170cd2403a8b2eac'}, 'json': None, 'origin': '195.134.167.217', 'url': 'https://httpbin.org/post'}
# {'Password': 'adm', 'Username': 'name'}

# %%
# challenge 3

response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
data = pd.DataFrame(search['items'])
data
# Out:
#                    name                       path  \
# 0   .0016.scavengerhunt  47222/.0016.scavengerhunt
# 1   .0009.scavengerhunt  97881/.0009.scavengerhunt
# 2   .0021.scavengerhunt  30351/.0021.scavengerhunt
# 3   .0023.scavengerhunt  55417/.0023.scavengerhunt
# 4   .0019.scavengerhunt  70751/.0019.scavengerhunt
# 5   .0002.scavengerhunt  88596/.0002.scavengerhunt
# 6   .0011.scavengerhunt  50896/.0011.scavengerhunt
# 7   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 8   .0014.scavengerhunt  49418/.0014.scavengerhunt
# 9   .0012.scavengerhunt  15534/.0012.scavengerhunt
# 10  .0001.scavengerhunt  98750/.0001.scavengerhunt
# 11  .0018.scavengerhunt  45525/.0018.scavengerhunt
# 12  .0013.scavengerhunt  89338/.0013.scavengerhunt
# 13  .0005.scavengerhunt  44639/.0005.scavengerhunt
# 14  .0020.scavengerhunt  55685/.0020.scavengerhunt
# 15  .0024.scavengerhunt  47222/.0024.scavengerhunt
# 16  .0015.scavengerhunt  91701/.0015.scavengerhunt
# 17  .0007.scavengerhunt  17020/.0007.scavengerhunt
# 18  .0003.scavengerhunt  60224/.0003.scavengerhunt
# 19  .0022.scavengerhunt  40303/.0022.scavengerhunt
# 20  .0010.scavengerhunt  47830/.0010.scavengerhunt
# 21  .0004.scavengerhunt  68848/.0004.scavengerhunt
# 22  .0017.scavengerhunt  70985/.0017.scavengerhunt
# 23  .0008.scavengerhunt  15534/.0008.scavengerhunt
#
#                                          sha  \
# 0   f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0
# 1   f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0
# 2   fb828e4a926b0a84fc16111fc0ee3eeec41f0ce7
# 3   04d0ffb8d895a9e3ee244493e829a24468bd1f60
# 4   09e16f36b3c4993ba924b1074629283a49869be9
# 5   1269488f7fb1f4b56a8c0e5eb48cecbfadfa9219
# 6   1a00a70b240d8947af0aaa04f1a93a52c72f7420
# 7   1c9064284a24b3486015eafdb391b141c27ada2b
# 8   1c9064284a24b3486015eafdb391b141c27ada2b
# 9   209e3ef4b6247ce746048d5711befda46206d235
# 10  2add7632f1323136324efbf38ec66db1838b6173
# 11  397b22b2dc371e8db59ed327f0b75321e4c0d0f2
# 12  3aaf448b40f878cf3067e2323616143bdde600de
# 13  3aaf448b40f878cf3067e2323616143bdde600de
# 14  41d25f51c301c5eee3737998b0d86573e4e91b90
# 15  47eb4306e5fec9e051dacabc7039348109784b94
# 16  6abb415e0ae3450be0f323113bcca2af195ebbff
# 17  6abb415e0ae3450be0f323113bcca2af195ebbff
# 18  ba524d7abc4b3a0c0995eb85c9eef470e9e7172f
# 19  bf3efa02f721c40c03a613824e345243a35f6812
# 20  c1187c4badc9be6990570cef850fc87dcf3523b0
# 21  d15a2cc44e31b14c65264271b81072e5ba0e1634
# 22  e351fb73264581ce26504b97ef07daea35116f32
# 23  e351fb73264581ce26504b97ef07daea35116f32
#
#                                                   url  \
# 0   https://api.github.com/repositories/162375181/...
# 1   https://api.github.com/repositories/162375181/...
# 2   https://api.github.com/repositories/162375181/...
# 3   https://api.github.com/repositories/162375181/...
# 4   https://api.github.com/repositories/162375181/...
# 5   https://api.github.com/repositories/162375181/...
# 6   https://api.github.com/repositories/162375181/...
# 7   https://api.github.com/repositories/162375181/...
# 8   https://api.github.com/repositories/162375181/...
# 9   https://api.github.com/repositories/162375181/...
# 10  https://api.github.com/repositories/162375181/...
# 11  https://api.github.com/repositories/162375181/...
# 12  https://api.github.com/repositories/162375181/...
# 13  https://api.github.com/repositories/162375181/...
# 14  https://api.github.com/repositories/162375181/...
# 15  https://api.github.com/repositories/162375181/...
# 16  https://api.github.com/repositories/162375181/...
# 17  https://api.github.com/repositories/162375181/...
# 18  https://api.github.com/repositories/162375181/...
# 19  https://api.github.com/repositories/162375181/...
# 20  https://api.github.com/repositories/162375181/...
# 21  https://api.github.com/repositories/162375181/...
# 22  https://api.github.com/repositories/162375181/...
# 23  https://api.github.com/repositories/162375181/...
#
#                                               git_url  \
# 0   https://api.github.com/repositories/162375181/...
# 1   https://api.github.com/repositories/162375181/...
# 2   https://api.github.com/repositories/162375181/...
# 3   https://api.github.com/repositories/162375181/...
# 4   https://api.github.com/repositories/162375181/...
# 5   https://api.github.com/repositories/162375181/...
# 6   https://api.github.com/repositories/162375181/...
# 7   https://api.github.com/repositories/162375181/...
# 8   https://api.github.com/repositories/162375181/...
# 9   https://api.github.com/repositories/162375181/...
# 10  https://api.github.com/repositories/162375181/...
# 11  https://api.github.com/repositories/162375181/...
# 12  https://api.github.com/repositories/162375181/...
# 13  https://api.github.com/repositories/162375181/...
# 14  https://api.github.com/repositories/162375181/...
# 15  https://api.github.com/repositories/162375181/...
# 16  https://api.github.com/repositories/162375181/...
# 17  https://api.github.com/repositories/162375181/...
# 18  https://api.github.com/repositories/162375181/...
# 19  https://api.github.com/repositories/162375181/...
# 20  https://api.github.com/repositories/162375181/...
# 21  https://api.github.com/repositories/162375181/...
# 22  https://api.github.com/repositories/162375181/...
# 23  https://api.github.com/repositories/162375181/...
#
#                                              html_url  \
# 0   https://github.com/ironhack-datalabs/scavenger...
# 1   https://github.com/ironhack-datalabs/scavenger...
# 2   https://github.com/ironhack-datalabs/scavenger...
# 3   https://github.com/ironhack-datalabs/scavenger...
# 4   https://github.com/ironhack-datalabs/scavenger...
# 5   https://github.com/ironhack-datalabs/scavenger...
# 6   https://github.com/ironhack-datalabs/scavenger...
# 7   https://github.com/ironhack-datalabs/scavenger...
# 8   https://github.com/ironhack-datalabs/scavenger...
# 9   https://github.com/ironhack-datalabs/scavenger...
# 10  https://github.com/ironhack-datalabs/scavenger...
# 11  https://github.com/ironhack-datalabs/scavenger...
# 12  https://github.com/ironhack-datalabs/scavenger...
# 13  https://github.com/ironhack-datalabs/scavenger...
# 14  https://github.com/ironhack-datalabs/scavenger...
# 15  https://github.com/ironhack-datalabs/scavenger...
# 16  https://github.com/ironhack-datalabs/scavenger...
# 17  https://github.com/ironhack-datalabs/scavenger...
# 18  https://github.com/ironhack-datalabs/scavenger...
# 19  https://github.com/ironhack-datalabs/scavenger...
# 20  https://github.com/ironhack-datalabs/scavenger...
# 21  https://github.com/ironhack-datalabs/scavenger...
# 22  https://github.com/ironhack-datalabs/scavenger...
# 23  https://github.com/ironhack-datalabs/scavenger...
#
#                                            repository  score
# 0   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 1   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 2   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 3   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 4   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 5   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 6   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 7   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 8   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 9   {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 10  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 11  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 12  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 13  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 14  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 15  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 16  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 17  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 18  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 19  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 20  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 21  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 22  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0
# 23  {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRv...    1.0

# %%
sorted(data.name)
# Out:
# ['.0001.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0006.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0012.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0024.scavengerhunt']

# %%
data.url
# Out:
# 0     https://api.github.com/repositories/162375181/...
# 1     https://api.github.com/repositories/162375181/...
# 2     https://api.github.com/repositories/162375181/...
# 3     https://api.github.com/repositories/162375181/...
# 4     https://api.github.com/repositories/162375181/...
# 5     https://api.github.com/repositories/162375181/...
# 6     https://api.github.com/repositories/162375181/...
# 7     https://api.github.com/repositories/162375181/...
# 8     https://api.github.com/repositories/162375181/...
# 9     https://api.github.com/repositories/162375181/...
# 10    https://api.github.com/repositories/162375181/...
# 11    https://api.github.com/repositories/162375181/...
# 12    https://api.github.com/repositories/162375181/...
# 13    https://api.github.com/repositories/162375181/...
# 14    https://api.github.com/repositories/162375181/...
# 15    https://api.github.com/repositories/162375181/...
# 16    https://api.github.com/repositories/162375181/...
# 17    https://api.github.com/repositories/162375181/...
# 18    https://api.github.com/repositories/162375181/...
# 19    https://api.github.com/repositories/162375181/...
# 20    https://api.github.com/repositories/162375181/...
# 21    https://api.github.com/repositories/162375181/...
# 22    https://api.github.com/repositories/162375181/...
# 23    https://api.github.com/repositories/162375181/...
# Name: url, dtype: object

# %%
message_string = ""
for i in data.url:
    message = requests.get(i).content
    message_string += str(message)  
message_string
# Out:
# 'b\'{"name":".0016.scavengerhunt","path":"47222/.0016.scavengerhunt","sha":"f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0","size":3,"url":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476","html_url":"https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt","git_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0","download_url":"https://raw.githubusercontent.com/ironhack-datalabs/scavenger/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt","type":"file","content":"aXMK\\\\n","encoding":"base64","_links":{"self":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476","git":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0","html":"https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt"}}\'b\'{"name":".0009.scavengerhunt","path":"97881/.0009.scavengerhunt","sha":"f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0","size":3,"url":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/97881/.0009.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476","html_url":"https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/97881/.0009.scavengerhunt","git_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0","download_url":"https://raw.githubusercontent.com/ironhack-datalabs/scavenger/9308ccc8a4c34c5e3a991ee815222a9691c32476/97881/.0009.scavengerhunt","type":"file","content":"aXMK\\\\n","encoding":"base64","_links":{"self":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/97881/.0009.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476","git":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0","html":"https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/97881/.0009.scavengerhunt"}}\'b\'{"name":".0021.scavengerhunt","path":"30351/.0021.scavengerhunt","sha":"fb828e4a926b0a84fc16111fc0ee3eeec41f0ce7","size":5,"url":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/30351/.0021.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476","html_url":"https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/30351/.0021.scavengerhunt","git_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/fb828e4a926b0a84fc16111fc0ee3eeec41f0ce7","download_url":"https://raw.githubusercontent.com/ironhack-datalabs/scavenger/9308ccc8a4c34c5e3a991ee815222a9691c32476/30351/.0021.scavengerhunt","type":"file","content":"bmVlZAo=\\\\n","encoding":"base64","_links":{"self":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/30351/.0021.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476","git":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/fb828e4a926b0a84fc16111fc0ee3eeec41f0ce7","html":"https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/30351/.0021.scavengerhunt"}}\'b\'{"name":".0023.scavengerhunt","path":"55417/.0023.scavengerhunt","sha":"04d0ffb8d895a9e3ee244493e829a24468bd1f60","size":8,"url":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/55417/.0023.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476","html_url":"https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/55417/.0023.scavengerhunt","git_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/04d0ffb8d895a9e3ee244493e829a24468bd1f60","download_url":"https://raw.githubusercontent.com/ironhack-datalabs/scavenger/9308ccc8a4 ...
