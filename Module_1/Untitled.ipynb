# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://en.wikipedia.org/wiki/List_of_the_most_common_passwords'
html = requests.get(url).content
html
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of the most common passwords - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"7d83416a-2d0b-44e1-ae47-3fc8e83015d6","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_the_most_common_passwords","wgTitle":"List of the most common passwords","wgCurRevisionId":1075270428,"wgRevisionId":1075270428,"wgArticleId":53900562,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Us
# ...

# %%
soup = BeautifulSoup(html, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of the most common passwords - Wikipedia</title>
# ...

# %%
table = soup.find_all('table', {'class':'wikitable'})[0]
table
# Out:
# <table class="wikitable">
# <caption>Top 20 most common passwords according to NordPass<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>2021
# </th></tr>
# <tr>
# <td>1
# </td>
# <td>123456
# </td></tr>
# <tr>
# <td>2
# </td>
# <td>123456789
# </td></tr>
# <tr>
# <td>3
# </td>
# <td>12345
# </td></tr>
# <tr>
# <td>4
# </td>
# <td>qwerty
# </td></tr>
# <tr>
# <td>5
# </td>
# <td>password
# </td></tr>
# <tr>
# <td>6
# </td>
# <td>12345678
# </td></tr>
# <tr>
# <td>7
# </td>
# <td>111111
# </td></tr>
# <tr>
# <td>8
# </td>
# <td>123123
# </td></tr>
# <tr>
# <td>9
# </td>
# <td>1234567890
# </td></tr>
# <tr>
# <td>10
# </td>
# <td>1234567
# </td></tr>
# <tr>
# <td>11
# </td>
# <td>qwerty123
# </td></tr>
# <tr>
# <td>12
# </td>
# <td>000000
# </td></tr>
# <tr>
# <td>13
# </td>
# <td>1q2w3e
# </td></tr>
# <tr>
# <td>14
# </td>
# <td>aa12345678
# </td></tr>
# <tr>
# <td>15
# </td>
# <td>abc123
# </td></tr>
# ...

# %%
rows = table.find_all('tr')
rows
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>2021
#  </th></tr>,
#  <tr>
#  <td>1
#  </td>
#  <td>123456
#  </td></tr>,
#  <tr>
#  <td>2
#  </td>
#  <td>123456789
#  </td></tr>,
#  <tr>
#  <td>3
#  </td>
#  <td>12345
#  </td></tr>,
#  <tr>
#  <td>4
#  </td>
#  <td>qwerty
#  </td></tr>,
#  <tr>
#  <td>5
#  </td>
#  <td>password
#  </td></tr>,
#  <tr>
#  <td>6
#  </td>
#  <td>12345678
#  </td></tr>,
#  <tr>
#  <td>7
#  </td>
#  <td>111111
#  </td></tr>,
#  <tr>
#  <td>8
#  </td>
#  <td>123123
#  </td></tr>,
#  <tr>
#  <td>9
#  </td>
#  <td>1234567890
#  </td></tr>,
#  <tr>
#  <td>10
#  </td>
#  <td>1234567
#  </td></tr>,
#  <tr>
#  <td>11
#  </td>
#  <td>qwerty123
#  </td></tr>,
#  <tr>
#  <td>12
#  </td>
#  <td>000000
#  </td></tr>,
#  <tr>
#  <td>13
#  </td>
#  <td>1q2w3e
#  </td></tr>,
#  <tr>
#  <td>14
#  </td>
#  <td>aa12345678
#  </td></tr>,
#  <tr>
#  <td>15
#  </td>
#  <td>abc123
#  </td></tr>,
#  <tr>
#  <td>16
#  </td>
#  <td>password1
#  </td></tr>,
#  <tr>
#  <td>17
#  </td>
# ...

# %%
rows = table.find_all('tr')
rows = [row.text.strip().split('\n') for row in rows]
rows
# Out:
# [['Rank', '', '2021'],
#  ['1', '', '123456'],
#  ['2', '', '123456789'],
#  ['3', '', '12345'],
#  ['4', '', 'qwerty'],
#  ['5', '', 'password'],
#  ['6', '', '12345678'],
#  ['7', '', '111111'],
#  ['8', '', '123123'],
#  ['9', '', '1234567890'],
#  ['10', '', '1234567'],
#  ['11', '', 'qwerty123'],
#  ['12', '', '000000'],
#  ['13', '', '1q2w3e'],
#  ['14', '', 'aa12345678'],
#  ['15', '', 'abc123'],
#  ['16', '', 'password1'],
#  ['17', '', '1234'],
#  ['18', '', 'qwertyuiop'],
#  ['19', '', '123321'],
#  ['20', '', 'password123']]

# %%
colnames = rows[0]
colnames
# Out:
# ['Rank', '', '2021']

# %%
data = rows[1:]
data
# Out:
# [['1', '', '123456'],
#  ['2', '', '123456789'],
#  ['3', '', '12345'],
#  ['4', '', 'qwerty'],
#  ['5', '', 'password'],
#  ['6', '', '12345678'],
#  ['7', '', '111111'],
#  ['8', '', '123123'],
#  ['9', '', '1234567890'],
#  ['10', '', '1234567'],
#  ['11', '', 'qwerty123'],
#  ['12', '', '000000'],
#  ['13', '', '1q2w3e'],
#  ['14', '', 'aa12345678'],
#  ['15', '', 'abc123'],
#  ['16', '', 'password1'],
#  ['17', '', '1234'],
#  ['18', '', 'qwertyuiop'],
#  ['19', '', '123321'],
#  ['20', '', 'password123']]

# %%
df = pd.DataFrame(data, columns = colnames)
df
# Out:
#    Rank           2021
# 0     1         123456
# 1     2      123456789
# 2     3          12345
# 3     4         qwerty
# 4     5       password
# 5     6       12345678
# 6     7         111111
# 7     8         123123
# 8     9     1234567890
# 9    10        1234567
# 10   11      qwerty123
# 11   12         000000
# 12   13         1q2w3e
# 13   14     aa12345678
# 14   15         abc123
# 15   16      password1
# 16   17           1234
# 17   18     qwertyuiop
# 18   19         123321
# 19   20    password123

# %%
r = requests.get('https://s3-eu-west-1.amazonaws.com/ih-materials/uploads/data-static/documents/forbidden')
if r.status_code < 300:
    print('request was successful')
elif r.status_code >= 400 and r.status_code < 500:
    print('request failed because the resource either does not exist or is forbidden')
else:
    print('request failed because the response server encountered an error')
# Out:
# request failed because the resource either does not exist or is forbidden

# %%
try:
    r = requests.get(url, timeout=10)
except requests.exceptions.Timeout:
    # timeout error... do something
except requests.exceptions.TooManyRedirects:
    # redirect error... do something
except requests.exceptions.SSLError:
    # ssl error... do something
except requests.exceptions.RequestException as e:
    # other unknown errors... do something
# Out:
#   File "/var/folders/9y/45l79l3x40s95c93b61_6txw0000gn/T/ipykernel_33345/2888477273.py", line 5
#     except requests.exceptions.TooManyRedirects:
#     ^
# IndentationError: expected an indented block
