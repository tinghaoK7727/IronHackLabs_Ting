# %%
import pandas as pd

# %%
data = pd.read_csv(r'/Users/tinghaokao/Desktop/data/Copy of MRR and Churn - Sheet3.csv')

# %%
data
# Out:
#     Unnamed: 0  Unnamed: 1        MRR Churn USD  Churn N Clients
# 0          NaN           1  12,123.00    708.00              NaN
# 1          NaN           2   9,105.00  3,816.00              NaN
# 2          NaN           3   8,851.00    499.00              NaN
# 3          NaN           4   7,273.13    779.87              NaN
# 4          NaN           5   6,571.13    500.00              NaN
# 5          NaN           6   8,391.13  1,060.70              NaN
# 6          NaN           7   7,716.13    675.00              NaN
# 7          NaN           8   7,786.13  1,060.70              NaN
# 8          NaN           9   7,786.13  1,060.70              NaN
# 9          NaN          10   7,704.13    447.00              NaN
# 10         NaN          11   7,774.13  1,060.70              NaN
# 11         NaN          12   6,644.00  1,060.70              NaN
# 12         NaN          13   7,442.00       NaN              NaN
# ...

# %%
data.set_index('Unnamed: 1', inplace = True)
data
# Out:
#             Unnamed: 0        MRR Churn USD  Churn N Clients
# Unnamed: 1
# 1                  NaN  12,123.00    708.00              NaN
# 2                  NaN   9,105.00  3,816.00              NaN
# 3                  NaN   8,851.00    499.00              NaN
# 4                  NaN   7,273.13    779.87              NaN
# 5                  NaN   6,571.13    500.00              NaN
# 6                  NaN   8,391.13  1,060.70              NaN
# 7                  NaN   7,716.13    675.00              NaN
# 8                  NaN   7,786.13  1,060.70              NaN
# 9                  NaN   7,786.13  1,060.70              NaN
# 10                 NaN   7,704.13    447.00              NaN
# 11                 NaN   7,774.13  1,060.70              NaN
# 12                 NaN   6,644.00  1,060.70              NaN
# 13                 NaN   7,442.00       NaN              NaN
# 14                 NaN   7,442.00       NaN              NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(data=data, y=)
plt.ylabel('MRR Value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 1'
#
# The above exception was the direct cause of the following exception:
#
# ...
