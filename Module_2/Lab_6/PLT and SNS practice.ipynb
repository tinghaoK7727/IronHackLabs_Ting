# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
x1 = np.arange(0,10,1)
x2 = np.linspace(0,5,10)

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter('a', 'b', c='g',s='d', data=data)

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b');

# %%
x = np.linspace(0, 5, 100)  # Sample data.

fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(x, x, label='linear', linestyle = ':', linewidth = 3)  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend();  # Add a legend.

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.set_ylim(-2, 2);

# %%
x = np.linspace(0, 5, 100)  # Sample data.

fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(x, x, label='linear', linestyle = ':', linewidth = 3)  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xticks([2, 4, 5])
ax.set_yticks(np.arange(0, 200, 20))
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend();  # Add a legend.

# %%
x = np.linspace(0, 5, 100) 
sns.histplot(x, multiple="stack")
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
f, ax =plt.subplots(1,2)

# %%
tips = sns.load_dataset("tips")

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=tips, x='day', y='tip', hue = 'smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.histplot(data=tips, x="total_bill", color="blue")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, y="tip", color = "green")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='tip'>

# %%
sns.histplot(data=tips, x="total_bill", binwidth=5, color="purple")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
penguins = sns.load_dataset("penguins")

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.histplot(data=penguins, x="flipper_length_mm", bins=10)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
mpg = sns.load_dataset("mpg")

mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.displot(data=mpg, x='mpg', hue='origin')

# %%
sns.histplot(mpg, x="mpg", hue="cylinders", element="poly", bins =12)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=tips, x="day", hue="sex", multiple = "dodge", shrink=.9)
# Out:
# <AxesSubplot:xlabel='day', ylabel='Count'>

# %%
sns.histplot(tips, x="total_bill", y="tip", color = "blue")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
